# %% [markdown]
# # Library BeautifulSoup is requird

# %%
# pip install beautifulsoup4

# %%
import os
def conditionalMkdir(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)

# %%
''' Obtains column labels from NHANES website and saves to JSON '''
def getLabel(file_dir, file_url, file_type):
    # Get data year
    year = getFileYear(file_url)

    # Combile file location:
    file_dir = os.path.join(file_dir, year, file_type)

    # Get name for file
    file_name = file_url.split('/')[-1].replace('.XPT', '.JSON')
    file_loc = os.path.join(file_dir, file_name)

    # Modify XPT file_url to load page with labels
    file_url = file_url.replace('.XPT', '.htm')

    # Check that file does not already exist
    if not os.path.isfile(file_loc):
        # Open the website and download source HTML
        with urllib.request.urlopen(file_url) as page:
            html_source = page.read()

        # Parse the website for column label
        file_labels = parsePageLabels(html_source)

        # Save the file to JSON
        print('Saving label data: %s' % file_loc)
        with open(file_loc, 'w') as open_file:
            json.dump(file_labels, open_file)
            
''' Parses a page for 'codebook' div with descriptions of column labels '''
def parsePageLabels(html_source):
    # Parse HTML source code with BeautifulSoup library
    soup = BeautifulSoup(html_source, 'html.parser')

    # Find div element with codebook
    try:
        div = soup.findAll('div', id="CodebookLinks")[0]
    except:
        # If we can't find the div, print
        print('Error, no CodebookLinks Div')
        return {}

    # Get all links and their text in the div
    labels = [link.string.rstrip() for link in div.findAll('a')]

    # Put labels into library
    labels = [re.split('( - )', label, 1) for label in labels]
    labels = {label[0]:label[-1] for label in labels}
    return labels

# %%
import os
import argparse
import urllib.request
import re
import json
import functools
from multiprocessing import Pool
import time



try:
        from BeautifulSoup import BeautifulSoup
except ImportError:
        from bs4 import BeautifulSoup


''' Finds all links to XPT files in source HTML '''
def parsePageXPT(html_source):
    # Parse HTML source code with BeautifulSoup library
    soup = BeautifulSoup(html_source, 'html.parser')

    # Get all <a>...</a> with .XPT extensions
    xpt_urls = soup.findAll('a', href=re.compile('\.XPT$'))
    xpt_urls = [url['href'] for url in xpt_urls]
    return xpt_urls

'''Get year associated with file '''
def getFileYear(file_url):
    # Search URL for a year
    year = re.search('\/(\d+-\d+)\/', file_url)

    # Get value from regular expression match
    if year:
        year = year.group(1)
    else:
        # If no match, assign year as 'Other'
        year = 'Other'

    return year

''' Creates directory for file and downloads file from provided URL '''
def getFile(file_dir, file_url, file_type):
    # Get data year
    year = getFileYear(file_url)
    if year == '2017-2018':
        # Compile file location
        file_dir = os.path.join(file_dir, year, file_type)

        # Make directory for file if necessary
        conditionalMkdir(file_dir)

        # Get name for file
        file_name = file_url.split('/')[-1]
        file_loc = os.path.join(file_dir, file_name)

        # Check that file does not already exist
        if not os.path.isfile(file_loc):
            print('Getting file: %s' % file_url)
            # Download the file and write to local

            urllib.request.urlretrieve(file_url, file_loc)

''' Reads HTML source from provided URLs, parses HTML for XPT files, and saves files '''
def parseWebSite(url, output_dir):
    # Get base URL for appending to relative file URLs
    base_url = 'http://' + url.lstrip('http://').split('/')[0]

    # Get file type for this URL
    file_type = re.search('Component=([a-zA-Z]+)', url)
    if file_type:
        file_type = file_type.group(1)
    else:
        file_type = 'Other'

    # Open the website and download source HTML
    with urllib.request.urlopen(url) as page:
        html_source = page.read()

    # Parse the website for .XPT file links
    file_urls = parsePageXPT(html_source)
    file_urls = [base_url + file_url for file_url in file_urls]

    # Download each file and store locally
    for file_url in file_urls:
        getFile(output_dir, file_url, file_type)

# %%
url = ['http://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?Component=Demographics',
'http://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?Component=Dietary',
'http://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?Component=Examination',
'http://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?Component=Laboratory',
'http://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?Component=Questionnaire',
'http://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?Component=Non-Public']

# %%
#  Demographics
output_dir = './data/raw_data/'
parseWebSite(url[0], output_dir)
# Out:
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DEMO_J.XPT
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-0da14e9f2eb7> in <module>
#       1 #  Demographics
#       2 output_dir = './data/raw_data/'
# ----> 3 parseWebSite(url[0], output_dir)
#
# <ipython-input-3-6f8232d465b0> in parseWebSite(url, output_dir)
#     106     # Download each file and store locally
#     107     for file_url in file_urls:
# --> 108         getFile(output_dir, file_url, file_type)
#
# <ipython-input-3-6f8232d465b0> in getFile(file_dir, file_url, file_type)
#      82             # Download the file and write to local
#      83
# ---> 84             urllib.request.urlretrieve(file_url, file_loc)
#      85
#      86 ''' Reads HTML source from provided URLs, parses HTML for XPT files, and saves files '''
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     274
#     275             while True:
# --> 276                 block = fp.read(bs)
#     277                 if not block:
#     278                     break
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in read(self, amt)
#     456             # Amount is given, implement using readinto
#     457             b = bytearray(amt)
# --> 458             n = self.readinto(b)
#     459             return memoryview(b)[:n].tobytes()
#     460         else:
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in readinto(self, b)
#     500         # connection, and the user is reading more bytes than will be provided
#     501         # (for example, reading in 1k chunks)
# --> 502         n = self.fp.readinto(b)
#     503         if not n and b:
#     504             # Ideally, we would raise IncompleteRead if the content-length
#
# ~/opt/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
#  Dietary
output_dir = './data/raw_data/'
parseWebSite(url[1], output_dir)
# Out:
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DR1IFF_J.XPT
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-39e7f94331fa> in <module>
#       1 #  Dietary
#       2 output_dir = './data/raw_data/'
# ----> 3 parseWebSite(url[1], output_dir)
#
# <ipython-input-3-6f8232d465b0> in parseWebSite(url, output_dir)
#     106     # Download each file and store locally
#     107     for file_url in file_urls:
# --> 108         getFile(output_dir, file_url, file_type)
#
# <ipython-input-3-6f8232d465b0> in getFile(file_dir, file_url, file_type)
#      82             # Download the file and write to local
#      83
# ---> 84             urllib.request.urlretrieve(file_url, file_loc)
#      85
#      86 ''' Reads HTML source from provided URLs, parses HTML for XPT files, and saves files '''
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = _splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in http_open(self, req)
#    1377
#    1378     def http_open(self, req):
# -> 1379         return self.do_open(http.client.HTTPConnection, req)
#    1380
#    1381     http_request = AbstractHTTPHandler.do_request_
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1348         try:
#    1349             try:
# -> 1350                 h.request(req.get_method(), req.selector, req.data, headers,
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#    1352             except OSError as err: # timeout error
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1253                 encode_chunked=False):
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#    1257     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1299             # default charset of iso-8859-1.
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#    1303     def getresponse(self):
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in endheaders(self, message_body, encode_chunked)
#    1248         else:
#    1249             raise CannotSendHeader()
# -> 1250         self._send_output(message_body, encode_chunked=encode_chunked)
#    1251
#    1252     def request(self, method, url, body=None, headers={}, *,
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in _send_output(self, message_body, encode_chunked)
#    1008         msg = b"\r\n".join(self._buffer)
#    1009         del self._buffer[:]
# -> 1010         self.send(msg)
#    1011
#    1012         if message_body is not None:
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in send(self, data)
#     948         if self.sock is None:
#     949             if self.auto_open:
# --> 950                 self.connect()
#     951             else:
#     952                 raise NotConnected()
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in connect(self)
#     919     def connect(self):
#     920         """Connect to the host and port specified in __init__."""
# --> 921         self.sock = self._create_connection(
#     922             (self.host,self.port), self.timeout, self.source_address)
#     923         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# ~/opt/anaconda3/lib/python3.8/socket.py in create_connection(address, timeout, source_address)
#     794             if source_address:
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#     798             err = None
#
# KeyboardInterrupt:

# %%
#  Examination
output_dir = './data/raw_data/'
parseWebSite(url[2], output_dir)

# %%
#  Laboratory
output_dir = './data/raw_data/'
parseWebSite(url[3], output_dir)
# Out:
# Saving label data: ./data/raw_data/2003-2004/Laboratory/L06AGE_C.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2005-2006/AMDGYD_D.XPT
# Saving label data: ./data/raw_data/2005-2006/Laboratory/AMDGYD_D.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/AMDGYD_H.XPT
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2013-2014/Laboratory/AMDGYD_H.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/AMDGYD_I.XPT
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2015-2016/Laboratory/AMDGYD_I.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/AMDGDS_H.XPT
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2013-2014/Laboratory/AMDGDS_H.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/1999-2000/SSAFB_A.XPT
# Saving label data: ./data/raw_data/1999-2000/Laboratory/SSAFB_A.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2007-2008/ALB_CR_E.XPT
# Saving label data: ./data/raw_data/2007-2008/Laboratory/ALB_CR_E.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/1999-2000/LAB16.XPT
# Saving label data: ./data/raw_data/1999-2000/Laboratory/LAB16.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2005-2006

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-d1b080331252> in <module>
#       1 #  Laboratory
#       2 output_dir = './data/raw_data/'
# ----> 3 parseWebSite(url[3], output_dir)
#
# <ipython-input-14-0b67dc13f17e> in parseWebSite(url, output_dir)
#     142     # Download each file and store locally
#     143     for file_url in file_urls:
# --> 144         getFile(output_dir, file_url, file_type)
#     145         getLabel(output_dir, file_url, file_type)
#
# <ipython-input-14-0b67dc13f17e> in getFile(file_dir, file_url, file_type)
#      85         # Download the file and write to local
#      86
# ---> 87         urllib.request.urlretrieve(file_url, file_loc)
#      88 #         print('sleep')
#      89 #         time.sleep(5)
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     274
#     275             while True:
# --> 276                 block = fp.read(bs)
#     277                 if not block:
#     278                     break
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in read(self, amt)
#     456             # Amount is given, implement using readinto
#     457             b = bytearray(amt)
# --> 458             n = self.readinto(b)
#     459             return memoryview(b)[:n].tobytes()
#     460         else:
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in readinto(self, b)
#     500         # connection, and the user is reading more bytes than will be provided
#     501         # (for example, reading in 1k chunks)
# --> 502         n = self.fp.readinto(b)
#     503         if not n and b:
#     504             # Ideally, we would raise IncompleteRead if the content-length
#
# ~/opt/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
#  Questionnaire
output_dir = './data/raw_data/'
parseWebSite(url[4], output_dir)
# Out:
# Saving label data: ./data/raw_data/2005-2006/Questionnaire/ACQ_D.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2007-2008/ACQ_E.XPT
# sleep
# Saving label data: ./data/raw_data/2007-2008/Questionnaire/ACQ_E.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/1999-2000/ACQ.XPT
# sleep
# Saving label data: ./data/raw_data/1999-2000/Questionnaire/ACQ.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2003-2004/ACQ_C.XPT
# sleep
# Saving label data: ./data/raw_data/2003-2004/Questionnaire/ACQ_C.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2001-2002/ACQ_B.XPT
# sleep
# Saving label data: ./data/raw_data/2001-2002/Questionnaire/ACQ_B.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2009-2010/ACQ_F.XPT
# sleep
# Saving label data: ./data/raw_data/2009-2010/Questionnaire/ACQ_F.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2011-2012/ACQ_G.XPT
# sleep
# Saving label data: ./data/raw_data/2011-2012/Questionnaire/ACQ_G.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/ACQ_H.XPT
# sleep
# Saving label data: ./data/raw_data/2013-2014/Questionnaire/ACQ_H.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/ACQ_I.XPT
# sleep
# Saving label data: ./data/raw_data/2015-2016/Questionnaire/ACQ_I.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/ACQ_J.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2017-2018/Questionnaire/ACQ_J.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2007-2008/AQQ_E.XPT
# sleep
# Saving label data: ./data/raw_data/2007-2008/Questionnaire/AQQ_E.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2009-2010/AQQ_F.XPT
# sleep
# Saving label data: ./data/raw_data/2009-2010/Questionnaire/AQQ_F.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2005-2006/ALQ_D.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2005-2006/Questionnaire/ALQ_D.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2007-2008/ALQ_E.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2007-2008/Questionnaire/ALQ_E.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/1999-2000/ALQ.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/1999-2000/Questionnaire/ALQ.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2003-2004/ALQ_C.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2003-2004/Questionnaire/ALQ_C.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2001-2002/ALQ_B.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2001-2002/Questionnaire/ALQ_B.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2009-2010/ALQ_F.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2009-2010/Questionnaire/ALQ_F.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2011-2012/ALQ_G.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2011-2012/Questionnaire/ALQ_G.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/ALQ_H.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2013-2014/Questionnaire/ALQ_H.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/ALQ_I.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2015-2016/Questionnaire/ALQ_I.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/ALQ_J.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2017-2018/Questionnaire/ALQ_J.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2009-2010/ALQY_F.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2009-2010/Questionnaire/ALQY_F.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2005-2006/AGQ_D.XPT
# sleep
# Saving label data: ./data/raw_data/2005-2006/Questionnaire/AGQ_D.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/1999-2000/RXQ_ANA.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/1999-2000/Questionnaire/RXQ_ANA.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2003-2004/RXQANA_C.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2003-2004/Questionnaire/RXQANA_C.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2001-2002/RXQANA_B.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2001-2002/Questionnaire/RXQANA_B.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2009-2010/ARQ_F.XPT
# sleep
# Saving label data: ./data/raw_data/2009-2010/Questionnaire/ARQ_F.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2007-2008/AUQ_E.XPT
# sleep
# Saving label data: ./data/raw_data/2007-2008/Questionnaire/AUQ_E.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/1999-2000/AUQ.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/1999-2000/Questionnaire/AUQ.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2005-2006/AUQ_D.XPT
# sleep
# Saving label data: ./data/raw_data/2005-2006/Questionnaire/AUQ_D.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2003-2004/AUQ_C.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2003-2004/Questionnaire/AUQ_C.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2001-2002/AUQ_B.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2001-2002/Questionnaire/AUQ_B.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2009-2010/AUQ_F.XPT
# sleep
# Saving label data: ./data/raw_data/2009-2010/Questionnaire/AUQ_F.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2011-2012/AUQ_G.XPT
# sleep
# Saving label data: ./data/raw_data/2011-2012/Questionnaire/AUQ_G.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/AUQ_I.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2015-2016/Questionnaire/AUQ_I.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/AUQ_J.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2017-2018/Questionnaire/AUQ_J.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/1999-2000/BAQ.XPT
# sleep
# Saving label data: ./data/raw_data/1999-2000/Questionnaire/BAQ.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2003-2004/BAQ_C.XPT
# sleep
# Saving label data: ./data/raw_data/2003-2004/Questionnaire/BAQ_C.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2001-2002/BAQ_B.XPT
# sleep
# Saving label data: ./data/raw_data/2001-2002/Questionnaire/BAQ_B.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2005-2006/BPQ_D.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2005-2006/Questionnaire/BPQ_D.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2007-2008/BPQ_E.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2007-2008/Questionnaire/BPQ_E.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/1999-2000/BPQ.XPT
# sleep
# Saving label data: ./data/raw_data/1999-2000/Questionnaire/BPQ.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2003-2004/BPQ_C.XPT
# sleep
# Saving label data: ./data/raw_data/2003-2004/Questionnaire/BPQ_C.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2001-2002/BPQ_B.XPT
# sleep
# Saving label data: ./data/raw_data/2001-2002/Questionnaire/BPQ_B.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2009-2010/BPQ_F.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2009-2010/Questionnaire/BPQ_F.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2011-2012/BPQ_G.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2011-2012/Questionnaire/BPQ_G.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/BPQ_H.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2013-2014/Questionnaire/BPQ_H.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/BPQ_I.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2015-2016/Questionnaire/BPQ_I.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/BPQ_J.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2017-2018/Questionnaire/BPQ_J.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/P_BPQ.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2017-2018/Questionnaire/P_BPQ.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2005-2006/BHQ_D.XPT
# sleep
# Saving label data: ./data/raw_data/2005-2006/Questionnaire/BHQ_D.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2007-2008/BHQ_E.XPT
# sleep
# Saving label data: ./data/raw_data/2007-2008/Questionnaire/BHQ_E.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2009-2010/BHQ_F.XPT
# sleep
# Saving label data: ./data/raw_data/2009-2010/Questionnaire/BHQ_F.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2005-2006/CDQ_D.XPT
# sleep
# Saving label data: ./data/raw_data/2005-2006/Questionnaire/CDQ_D.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2007-2008/CDQ_E.XPT
# sleep
# Saving label data: ./data/raw_data/2007-2008/Questionnaire/CDQ_E.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/1999-2000/CDQ.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/1999-2000/Questionnaire/CDQ.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2003-2004/CDQ_C.XPT
# sleep
# Saving label data: ./data/raw_data/2003-2004/Questionnaire/CDQ_C.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2001-2002/CDQ_B.XPT
# sleep
# Saving label data: ./data/raw_data/2001-2002/Questionnaire/CDQ_B.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2009-2010/CDQ_F.XPT
# sleep
# Saving label data: ./data/raw_data/2009-2010/Questionnaire/CDQ_F.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2011-2012/CDQ_G.XPT
# sleep
# Saving label data: ./data/raw_data/2011-2012/Questionnaire/CDQ_G.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/CDQ_H.XPT
# sleep
# Saving label data: ./data/raw_data/2013-2014/Questionnaire/CDQ_H.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/CDQ_I.XPT
# sleep
# Saving label data: ./data/raw_data/2015-2016/Questionnaire/CDQ_I.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/CDQ_J.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2017-2018/Questionnaire/CDQ_J.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/P_CDQ.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2017-2018/Questionnaire/P_CDQ.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/1999-2000/CFQ.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/1999-2000/Questionnaire/CFQ.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2001-2002/CFQ_B.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2001-2002/Questionnaire/CFQ_B.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2011-2012/CFQ_G.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2011-2012/Questionnaire/CFQ_G.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/CFQ_H.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2013-2014/Questionnaire/CFQ_H.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2007-2008/CBQ_E.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2007-2008/Questionnaire/CBQ_E.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2009-2010/CBQ_F.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2009-2010/Questionnaire/CBQ_F.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2011-2012/CBQ_G.XPT
# sleep
# Saving label data: ./data/raw_data/2011-2012/Questionnaire/CBQ_G.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/CBQ_H.XPT
# sleep
# Saving label data: ./data/raw_data/2013-2014/Questionnaire/CBQ_H.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/CBQ_I.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2015-2016/Questionnaire/CBQ_I.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/CBQ_J.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2017-2018/Questionnaire/CBQ_J.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2007-2008/CBQPFA_E.XPT
# sleep
# Saving label data: ./data/raw_data/2007-2008/Questionnaire/CBQPFA_E.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2009-2010/CBQPFA_F.XPT
# sleep
# Saving label data: ./data/raw_data/2009-2010/Questionnaire/CBQPFA_F.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/CBQPFA_J.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2017-2018/Questionnaire/CBQPFA_J.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2007-2008/CBQPFC_E.XPT
# sleep
# Saving label data: ./data/raw_data/2007-2008/Questionnaire/CBQPFC_E.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2009-2010/CBQPFC_F.XPT
# sleep
# Saving label data: ./data/raw_data/2009-2010/Questionnaire/CBQPFC_F.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/CBQPFC_J.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2017-2018/Questionnaire/CBQPFC_J.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2011-2012/CKQ_G.XPT
# sleep
# Saving label data: ./data/raw_data/2011-2012/Questionnaire/CKQ_G.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/CKQ_H.XPT
# sleep
# Saving label data: ./data/raw_data/2013-2014/Questionnaire/CKQ_H.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2005-2006/HSQ_D.XPT
# sleep
# Saving label data: ./data/raw_data/2005-2006/Questionnaire/HSQ_D.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2007-2008/HSQ_E.XPT
# sleep
# Saving label data: ./data/raw_data/2007-2008/Questionnaire/HSQ_E.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/1999-2000/HSQ.XPT
# sleep
# Saving label data: ./data/raw_data/1999-2000/Questionnaire/HSQ.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2003-2004/HSQ_C.XPT
# sleep
# Saving label data: ./data/raw_data/2003-2004/Questionnaire/HSQ_C.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2001-2002/HSQ_B.XPT
# sleep
# Saving label data: ./data/raw_data/2001-2002/Questionnaire/HSQ_B.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2009-2010/HSQ_F.XPT
# sleep
# Saving label data: ./data/raw_data/2009-2010/Questionnaire/HSQ_F.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2011-2012/HSQ_G.XPT
# sleep
# Saving label data: ./data/raw_data/2011-2012/Questionnaire/HSQ_G.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/HSQ_H.XPT
# sleep
# Saving label data: ./data/raw_data/2013-2014/Questionnaire/HSQ_H.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/HSQ_I.XPT
# sleep
# Saving label data: ./data/raw_data/2015-2016/Questionnaire/HSQ_I.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/HSQ_J.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2017-2018/Questionnaire/HSQ_J.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/P_HSQ.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2017-2018/Questionnaire/P_HSQ.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2005-2006/DEQ_D.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2005-2006/Questionnaire/DEQ_D.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/1999-2000/DEQ.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/1999-2000/Questionnaire/DEQ.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2003-2004/DEQ_C.XPT
# sleep
# Saving label data: ./data/raw_data/2003-2004/Questionnaire/DEQ_C.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2001-2002/DEQ_B.XPT
# sleep
# Saving label data: ./data/raw_data/2001-2002/Questionnaire/DEQ_B.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2009-2010/DEQ_F.XPT
# sleep
# Saving label data: ./data/raw_data/2009-2010/Questionnaire/DEQ_F.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/DEQ_H.XPT
# sleep
# Saving label data: ./data/raw_data/2013-2014/Questionnaire/DEQ_H.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2011-2012/DEQ_G.XPT
# sleep
# Saving label data: ./data/raw_data/2011-2012/Questionnaire/DEQ_G.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/DEQ_I.XPT
# sleep
# Saving label data: ./data/raw_data/2015-2016/Questionnaire/DEQ_I.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DEQ_J.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2017-2018/Questionnaire/DEQ_J.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/P_DEQ.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2017-2018/Questionnaire/P_DEQ.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2007-2008/DIQ_E.XPT
# sleep
# Saving label data: ./data/raw_data/2007-2008/Questionnaire/DIQ_E.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/1999-2000/DIQ.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/1999-2000/Questionnaire/DIQ.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2005-2006/DIQ_D.XPT
# sleep
# Saving label data: ./data/raw_data/2005-2006/Questionnaire/DIQ_D.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2003-2004/DIQ_C.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2003-2004/Questionnaire/DIQ_C.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2001-2002/DIQ_B.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2001-2002/Questionnaire/DIQ_B.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2009-2010/DIQ_F.XPT
# sleep
# Saving label data: ./data/raw_data/2009-2010/Questionnaire/DIQ_F.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2011-2012/DIQ_G.XPT
# sleep
# Saving label data: ./data/raw_data/2011-2012/Questionnaire/DIQ_G.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/DIQ_H.XPT
# sleep
# Saving label data: ./data/raw_data/2013-2014/Questionnaire
B.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2005-2006/DPQ_D.XPT
# sleep
# Saving label data: ./data/raw_data/2005-2006/Questionnaire/DPQ_D.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2007-2008/DPQ_E.XPT
# sleep
# Saving label data: ./data/raw_data/2007-2008/Questionnaire/DPQ_E.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2009-2010/DPQ_F.XPT
# sleep
# Saving label data: ./data/raw_data/2009-2010/Questionnaire/DPQ_F.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2011-2012/DPQ_G.XPT
# sleep
# Saving label data: ./data/raw_data/2011-2012/Questionnaire/DPQ_G.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/DPQ_H.XPT
# sleep
# Saving label data: ./data/raw_data/2013-2014/Questionnaire/DPQ_H.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/DPQ_I.XPT
# sleep
# Saving label data: ./data/raw_data/2015-2016/Questionnaire/DPQ_I.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DPQ_J.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2017-2018/Questionnaire/DPQ_J.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/P_DPQ.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2017-2018/Questionnaire/P_DPQ.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/1999-2000/CIQGAD.XPT
# sleep
# Saving label data: ./data/raw_data/1999-2000/Questionnaire/CIQGAD.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2003-2004/CIQGAD_C.XPT
# sleep
# Saving label data: ./data/raw_data/2003-2004/Questionnaire/CIQGAD_C.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2001-2002/CIQGAD_B.XPT
# sleep
# Saving label data: ./data/raw_data/2001-2002/Questionnaire/CIQGAD_B.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/1999-2000/CIQPANIC.XPT
# sleep
# Saving label data: ./data/raw_data/1999-2000/Questionnaire/CIQPANIC.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2003-2004/CIQPAN_C.XPT
# sleep
# Saving label data: ./data/raw_data/2003-2004/Questionnaire/CIQPAN_C.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2001-2002/CIQPAN_B.XPT
# sleep
# Saving label data: ./data/raw_data/2001-2002/Questionnaire/CIQPAN_B.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/1999-2000/MPQ.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/1999-2000/Questionnaire/MPQ.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2003-2004/MPQ_C.XPT
# sleep
# Saving label data: ./data/raw_data/2003-2004/Questionnaire/MPQ_C.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2001-2002/MPQ_B.XPT
# sleep
# Saving label data: ./data/raw_data/2001-2002/Questionnaire/MPQ_B.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/1999-2000/OCQ.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/1999-2000/Questionnaire/OCQ.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2003-2004/OCQ_C.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2003-2004/Questionnaire/OCQ_C.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2001-2002/OCQ_B.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2001-2002/Questionnaire/OCQ_B.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2005-2006/OCQ_D.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2005-2006/Questionnaire/OCQ_D.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2007-2008/OCQ_E.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2007-2008/Questionnaire/OCQ_E.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2009-2010/OCQ_F.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2009-2010/Questionnaire/OCQ_F.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2011-2012/OCQ_G.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2011-2012/Questionnaire/OCQ_G.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/OCQ_H.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2013-2014/Questionnaire/OCQ_H.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/OCQ_I.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2015-2016/Questionnaire/OCQ_I.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/OCQ_J.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2017-2018/Questionnaire/OCQ_J.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2007-2008/OHQ_E.XPT
# sleep
# Saving label data: ./data/raw_data/2007-2008/Questionnaire/OHQ_E.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/1999-2000/OHQ.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/1999-2000/Questionnaire/OHQ.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2005-2006/OHQ_D.XPT
# sleep
# Saving label data: ./data/raw_data/2005-2006/Questionnaire/OHQ_D.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2003-2004/OHQ_C.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2003-2004/Questionnaire/OHQ_C.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2001-2002/OHQ_B.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2001-2002/Questionnaire/OHQ_B.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2009-2010/OHQ_F.XPT
# sleep
# Saving label data: ./data/raw_data/2009-2010/Questionnaire/OHQ_F.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2011-2012/OHQ_G.XPT
# sleep
# Saving label data: ./data/raw_data/2011-2012/Questionnaire/OHQ_G.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/OHQ_H.XPT
# sleep
# Saving label data: ./data/raw_data/2013-2014/Questionnaire/OHQ_H.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/OHQ_I.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2015-2016/Questionnaire/OHQ_I.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/OHQ_J.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2017-2018/Questionnaire/OHQ_J.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/P_OHQ.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2017-2018/Questionnaire/P_OHQ.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2007-2008/OSQ_E.XPT
# sleep
# Saving label data: ./data/raw_data/2007-2008/Questionnaire/OSQ_E.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/1999-2000/OSQ.XPT
# sleep
# Saving label data: ./data/raw_data/1999-2000/Questionnaire/OSQ.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2005-2006/OSQ_D.XPT
# sleep
# Saving label data: ./data/raw_data/2005-2006/Questionnaire/OSQ_D.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2003-2004/OSQ_C.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2003-2004/Questionnaire/OSQ_C.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2001-2002/OSQ_B.XPT
# sleep
# Saving label data: ./data/raw_data/2001-2002/Questionnaire/OSQ_B.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2009-2010/OSQ_F.XPT
# sleep
# Saving label data: ./data/raw_data/2009-2010/Questionnaire/OSQ_F.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/OSQ_H.XPT
# sleep
# Saving label data: ./data/raw_data/2013-2014/Questionnaire/OSQ_H.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/OSQ_J.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2017-2018/Questionnaire/OSQ_J.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2007-2008/PUQMEC_E.XPT
# sleep
# Saving label data: ./data/raw_data/2007-2008/Questionnaire/PUQMEC_E.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/1999-2000/PUQ.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/1999-2000/Questionnaire/PUQ.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2005-2006/PUQMEC_D.XPT
# sleep
# Saving label data: ./data/raw_data/2005-2006/Questionnaire/PUQMEC_D.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2003-2004/PUQ_C.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2003-2004/Questionnaire/PUQ_C.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2001-2002/PUQ_B.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2001-2002/Questionnaire/PUQ_B.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2009-2010/PUQMEC_F.XPT
# sleep
# Saving label data: ./data/raw_data/2009-2010/Questionnaire/PUQMEC_F.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2011-2012/PUQMEC_G.XPT
# sleep
# Saving label data: ./data/raw_data/2011-2012/Questionnaire/PUQMEC_G.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/PUQMEC_H.XPT
# sleep
# Saving label data: ./data/raw_data/2013-2014/Questionnaire/PUQMEC_H.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/PUQMEC_I.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2015-2016/Questionnaire/PUQMEC_I.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/PUQMEC_J.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2017-2018/Questionnaire/PUQMEC_J.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/P_PUQMEC.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2017-2018/Questionnaire/P_PUQMEC.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2007-2008/PAQ_E.XPT
# sleep
# Error, no CodebookLinks Div
# Saving label data: ./data/raw_data/2007-2008/Questionnaire/PAQ_E.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/1999-2000/PAQ.XPT
# sleep
# Saving label data: ./data/raw_data/1999-2000/Questionnaire/PAQ.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2005-2006/PAQ_D.XPT
# sleep
# Saving label data: ./data/raw_data/2005-2006/Questionnaire/PAQ_D.JSON
# Getting file: http://wwwn.cdc.gov/Nchs/Nhanes/2003-2004/PAQ_C.XPT
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# <ipython-input-12-94a311b4d8c5> in <module>
#       1 #  Questionnaire
#       2 output_dir = './data/raw_data/'
# ----> 3 parseWebSite(url[4], output_dir)
#
# <ipython-input-11-8fad32ff5a52> in parseWebSite(url, output_dir)
#     142     # Download each file and store locally
#     143     for file_url in file_urls:
# --> 144         getFile(output_dir, file_url, file_type)
#     145         getLabel(output_dir, file_url, file_type)
#
# <ipython-input-11-8fad32ff5a52> in getFile(file_dir, file_url, file_type)
#      85         # Download the file and write to local
#      86
# ---> 87         urllib.request.urlretrieve(file_url, file_loc)
#      88         print('sleep')
#      89         time.sleep(5)
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = _splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in https_open(self, req)
#    1391
#    1392         def https_open(self, req):
# -> 1393             return self.do_open(http.client.HTTPSConnection, req,
#    1394                 context=self._context, check_hostname=self._check_hostname)
#    1395
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1352             except OSError as err: # timeout error
#    1353                 raise URLError(err)
# -> 1354             r = h.getresponse()
#    1355         except:
#    1356             h.close()
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~/opt/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# ConnectionResetError: [Errno 54] Connection reset by peer
